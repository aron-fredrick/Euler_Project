# %%
import math
import numpy as np
a = []
b = []
c = []

for ii in range(1,335):
    for jj in range(ii,500):
        hypot = math.sqrt(ii**2+jj**2)
        if hypot%1==0:
            a.append(ii)
            b.append(jj)
            c.append(hypot)
                
p = np.array(a)+np.array(b)+np.array(c)
statistics.mode(p)
# Out:
# 840.0

# %%
import statistics

# %%
p.sort()

# %%
p
# Out:
# array([   12.,    24.,    30.,    36.,    40.,    48.,    56.,    60.,
#           60.,    70.,    72.,    80.,    84.,    84.,    90.,    90.,
#           96.,   108.,   112.,   120.,   120.,   120.,   126.,   132.,
#          132.,   140.,   144.,   144.,   150.,   154.,   156.,   160.,
#          168.,   168.,   168.,   176.,   180.,   180.,   180.,   182.,
#          192.,   198.,   200.,   204.,   208.,   210.,   210.,   216.,
#          220.,   224.,   228.,   234.,   240.,   240.,   240.,   240.,
#          252.,   252.,   252.,   260.,   264.,   264.,   270.,   270.,
#          276.,   280.,   280.,   280.,   286.,   288.,   288.,   300.,
#          300.,   306.,   308.,   312.,   312.,   320.,   324.,   330.,
#          330.,   336.,   336.,   336.,   340.,   348.,   350.,   352.,
#          360.,   360.,   360.,   360.,   364.,   372.,   374.,   378.,
#          380.,   384.,   390.,   390.,   392.,   396.,   396.,   396.,
# ...
